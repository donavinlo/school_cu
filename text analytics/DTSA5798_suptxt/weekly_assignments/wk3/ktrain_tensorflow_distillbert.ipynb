# %% [markdown]
# # Imports

# %% [markdown]
# We're going to be using Google's Tensorflow package:
# https://www.tensorflow.org/tutorials
#
# We're using an API wrapper for Tensorflow called ktrain. It's absolutely fabulous because it really abstracts the whole deep learning process into a workflow so easy, even a computational social scientist can do it:
# https://github.com/amaiya/ktrain

# %%
import os
from sklearn.model_selection import train_test_split
import tensorflow as tf
print(tf.__version__)
try:
  import ktrain
except:
  # !pip install ktrain
  os.kill(os.getpid(), 9)
from ktrain import text
from ktrain.text import texts_from_df
import time
import pandas as pd
from keras.preprocessing.text import Tokenizer
import pickle
import json
import glob
import json
import numpy as np
# Out:
# 2.8.0

# %% [markdown]
# #Set your google colab runtime to use GPU, a must for deep learning!
# Runtime > Change Runtime Type > GPU

# %% [markdown]
# Let's download our data. For this project, we're going to be using data from Kaggle. Whenever you're on the hunt for some data to play around with in the predictive modeling word, Kaggle's database of datasets is a great place to poke around. Our data comes from Kaggle's News Category database:
# https://www.kaggle.com/rmisra/news-category-dataset/version/2

# %% [markdown]
# The syntax to fetch a file from a URL and save it to your Google Drive is:
# ```
# !wget <URL> -P <COLAB PATH>
# ```

# %%
# !wget http://128.138.93.164/news_category_trainingdata.json -P /content/drive/MyDrive/Colab_Notebooks/dtsa5798/wk3
# Out:
# --2022-05-01 22:26:17--  http://128.138.93.164/news_category_trainingdata.json
# Connecting to 128.138.93.164:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 78875614 (75M) [application/json]
# Saving to: ‘/content/drive/MyDrive/Colab_Notebooks/dtsa5798/wk3/news_category_trainingdata.json’
#
# news_category_train 100%[===================>]  75.22M  19.6MB/s    in 4.8s
#
# 2022-05-01 22:26:22 (15.8 MB/s) - ‘/content/drive/MyDrive/Colab_Notebooks/dtsa5798/wk3/news_category_trainingdata.json’ saved [78875614/78875614]

# %%
ROOT_DIR = "/content/drive/MyDrive/Colab_Notebooks/dtsa5798/wk3"
DATA_DIR = "%s" % ROOT_DIR
EVAL_DIR = "%s/evaluation" % ROOT_DIR
MODEL_DIR = "%s/models" % ROOT_DIR

# %% [markdown]
# I took the liberty of altering the data structure of the .jsonl to a json format that is native with pandas, so we can load it in with one line. If you're curious, our data structure here is a collection of json entries, one per line. We can load it to a pandas dataframe like so.
#
# ```
# json_file = open('News_Category_Dataset_v2.json', 'r')
# columns = ['category', 'headline', 'authors', 'link', 'short_description', 'date']
#
# training_data = pd.DataFrame(columns = columns)
#
# for i, aline in enumerate(json_file):
#   parsed_json = json.loads(aline)
#   for acolumn in columns:
#     training_data = training_data.append(pd.Series(name=i, dtype='float64'))
#     training_data[acolumn][i] = parsed_json[acolumn]
#   if i % 1000 == 0:
#       print(i)
# ```

# %%
reviews = pd.read_json('%s/news_category_trainingdata.json' % DATA_DIR)

# %% [markdown]
# Every time pandas handles a data format in a one-liner, an angel gets its wings. It's a beautiful, albeit rare thing.

# %% [markdown]
# #Preparing the Data

# %%
reviews.head()
# Out:
#         category                                           headline  \
# 0          CRIME  There Were 2 Mass Shootings In Texas Last Week...
# 1  ENTERTAINMENT  Will Smith Joins Diplo And Nicky Jam For The 2...
# 2  ENTERTAINMENT    Hugh Grant Marries For The First Time At Age 57
# 3  ENTERTAINMENT  Jim Carrey Blasts 'Castrato' Adam Schiff And D...
# 4  ENTERTAINMENT  Julianna Margulies Uses Donald Trump Poop Bags...
#
#            authors                                               link  \
# 0  Melissa Jeltsen  https://www.huffingtonpost.com/entry/texas-ama...
# 1    Andy McDonald  https://www.huffingtonpost.com/entry/will-smit...
# 2       Ron Dicker  https://www.huffingtonpost.com/entry/hugh-gran...
# 3       Ron Dicker  https://www.huffingtonpost.com/entry/jim-carre...
# 4       Ron Dicker  https://www.huffingtonpost.com/entry/julianna-...
#
#                                    short_description       date
# 0  She left her husband. He killed their children... 2018-05-26
# 1                           Of course it has a song. 2018-05-26
# 2  The actor and his longtime girlfriend Anna Ebe... 2018-05-26
# 3  The actor gives Dems an ass-kicking for not fi... 2018-05-26
# 4  The "Dietland" actress said using the bags is ... 2018-05-26

# %% [markdown]
# Most machine learning tools in Python accept one field/column/string. So we have to merge our two text column. Let's separate it with a space.

# %%
reviews['combined_text'] = reviews['headline'] + ' ' + reviews['short_description']

# %% [markdown]
# The first thing we need to do is prepare the data. Specifically, we have a categorical column that we want to turn into a "is this article healthy living?" column. That is, when an article is about healthy living, it should have a 1, when it's anything else, it should be a 0.

# %%
reviews[reviews['category'].str.contains("HEALTHY LIVING")]
# Out:
#               category                                           headline  \
# 7578    HEALTHY LIVING  To The People Who Say ‘I’m Tired’ When Someone...
# 7693    HEALTHY LIVING  Eating Shake Shack Made Me Feel Healthier Than...
# 7747    HEALTHY LIVING  How To Stay Updated On The News Without Losing...
# 7927    HEALTHY LIVING  27 Perfect Tweets About Whole30 That Will Make...
# 7934    HEALTHY LIVING         The Real Reason Your Hands Are Always Cold
# ...                ...                                                ...
# 124913  HEALTHY LIVING  Why You Need Both a 'Bouncer' and a 'Bartender...
# 124914  HEALTHY LIVING  How Video Games Can Improve Dialogue on Mental...
# 124925  HEALTHY LIVING  Wake-Up Calls Inspired My Change From Overdriv...
# 124950  HEALTHY LIVING        Loving a Narcissist Without Losing Yourself
# 124988  HEALTHY LIVING                            Reasons Not to Be Happy
#
#                                                   authors  \
# 7578    The Mighty, ContributorWe face disability, dis...
# 7693    Colleen Werner, ContributorCampus Editor-at-Large
# 7747                                       Lindsay Holmes
# 7927                                       Lindsay Holmes
# 7934    Refinery29, ContributorThe #1 new-media brand ...
# ...                                                   ...
# 124913  Elizabeth Grace Saunders, ContributorFounder, ...
# 124914         Mona Shattell, Contributornurse researcher
# 124925  Jane Shure, ContributorLeadership Coach, Psych...
# 124950  Nancy Colier, ContributorPsychotherapist, inte...
# 124988  Mindy Utay, Contributor"Calming Life's Conflicts"
#
#                                                      link  \
# 7578    https://www.huffingtonpost.com/entry/to-the-pe...
# 7693    https://www.huffingtonpost.com/entry/eating-sh...
# 7747    https://www.huffingtonpost.com/entry/anxiety-f...
# 7927    https://www.huffingtonpost.com/entry/tweets-ab...
# 7934    https://www.huffingtonpost.com/entry/the-real-...
# ...                                                   ...
# 124913  https://www.huffingtonpost.com/entry/happy-hea...
# 124914  https://www.huffingtonpost.com/entry/mental-il...
# 124925  https://www.huffingtonpost.com/entry/wake-up-c...
# 124950  https://www.huffingtonpost.com/entry/narcissis...
# 124988  https://www.huffingtonpost.com/entry/happiness...
#
#                                         short_description       date  \
# 7578    When you feel like this, it’s important to kno... 2018-01-16
# 7693    I can vividly remember the first time I felt f... 2018-01-12
# 7747       Because it's only becoming more of a struggle. 2018-01-12
# 7927    "The only Whole30 I want to participate in is ... 2018-01-10
# 7934    Essentially, your hands are kept warm thanks t... 2018-01-10
# ...                                                   ...        ...
# 124913  Instead of judging whether you made the right ... 2014-04-18
# 124914  While there are strong arguments for the games... 2014-04-18
# 124925  My wake-up call marching orders were clear: No... 2014-04-18
# 124950  It is very difficult for some people to see an... 2014-04-18
# 124988  Our thoughts and feelings are powerful, but ma... 2014-04-18
#
#                                             combined_text
# 7578    To The People Who Say ‘I’m Tired’ When Someone...
# 7693    Eating Shake Shack Made Me Feel Healthier Than...
# 7747    How To Stay Updated On The News Without Losing...
# 7927    27 Perfect Tweets About Whole30 That Will Make...
# 7934    The Real Reason Your Hands Are Always Cold Ess...
# ...                                                   ...
# 124913  Why You Need Both a 'Bouncer' and a 'Bartender...
# 124914  How Video Games Can Improve Dialogue on Mental...
# 124925  Wake-Up Calls Inspired My Change From Overdriv...
# 124950  Loving a Narcissist Without Losing Yourself It...
# 124988  Reasons Not to Be Happy Our thoughts and feeli...
#
# [6694 rows x 7 columns]

# %% [markdown]
# A quick pandas search soes that we have 6.7 articles that are about healthy living. The following line of code uses numpy's where functionality to help us recode the data. When "Healthy Living" appears in the "category" column, we'll label the "healthy" column with a 1. When it doesn't, it'll be 0.

# %%
reviews['healthy'] = np.where((reviews['category'] == 'HEALTHY LIVING'), 1, 0)

# %%
reviews['healthy'].describe()
# Out:
# count    200853.000000
# mean          0.033328
# std           0.179492
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.000000
# max           1.000000
# Name: healthy, dtype: float64

# %% [markdown]
# Yes! We're seeing the 1's where we'd expect.

# %% [markdown]
# So our data is very unbalanced. We have 6694 articles about healthly living, and about 194k that are not. If we give a machine learning algorithm this much negative evidence, it'll end up tuning itself to label everything as 0's more often than not. So, let's balance our data we have 6694 articles that are healthy living, and 6694 that are not!

# %%
sample_amount = 6694

healthy = reviews[reviews['healthy'] == 1]
not_healthy = reviews[reviews['healthy'] == 0].sample(n=sample_amount)

# %%
review_sample = pd.concat([healthy,not_healthy])

# %%
review_sample.describe()
# Out:
#             healthy
# count  13388.000000
# mean       0.500000
# std        0.500019
# min        0.000000
# 25%        0.000000
# 50%        0.500000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# A mean of .5 means these datasets are now perfectly balanced! And the N = 2*6694!

# %% [markdown]
# # Test, Tune and Save Models

# %%
target_names = ['NOT HEALTHY LIVING','HEALTHY LIVING']

# %%
tf.keras.backend.clear_session() #clears the current state of running the model. This will prevent training on top of training (overfitting).
t = text.Transformer('distilbert-base-uncased', maxlen=512, class_names=target_names)
# #other models you might try 'roberta-base', 'bert-base-uncased', 'distilroberta-base'
#we're going to use 'distilbert-base-uncased' for our model here
#ktrain lets us try some of the pretrained models available on huggingface
#you can browse all the models here: https://huggingface.co/transformers/pretrained_models.html
#some work, some dont, try at your own risk.
# Out:
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]

# %% [markdown]
# *   **maxlen** states the maximum amount of tokens(words) we are allowed to use
# *   **verbose** set to 1 allows it to print an output

# %%
train, val, preprocess = texts_from_df(review_sample, 'combined_text', label_columns=['healthy'], val_df=None, max_features=20000, maxlen=512, val_pct=0.1, ngram_range=1, preprocess_mode='distilbert', verbose=1)
# Out:
# ['not_healthy', 'healthy']
#         not_healthy  healthy
# 39411           0.0      1.0
# 70550           1.0      0.0
# 76329           1.0      0.0
# 126809          1.0      0.0
# 161782          1.0      0.0
# ['not_healthy', 'healthy']
#         not_healthy  healthy
# 110864          0.0      1.0
# 124202          0.0      1.0
# 40300           0.0      1.0
# 52643           0.0      1.0
# 86970           0.0      1.0
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# preprocessing train...
# language: en
# train sequence lengths:
# 	mean : 29
# 	95percentile : 58
# 	99percentile : 70
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Is Multi-Label? False
# preprocessing test...
# language: en
# test sequence lengths:
# 	mean : 29
# 	95percentile : 58
# 	99percentile : 72
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
model = preprocess.get_classifier()
learner = ktrain.get_learner(model, train_data=train, val_data=val, batch_size=16)
# batch size are typically 16 and under and an even number

# %%
learner.lr_find(max_epochs=6)#epoch is just the # of trials going through the data
# Out:
# simulating training for different learning rates... this may take a few moments...
# Epoch 1/6
# 730/753 [============================>.] - ETA: 40s - loss: 0.6593 - accuracy: 0.6416

# %%
learner.lr_plot() #10-4 is the best learning rate according to this graph

# %%
history=learner.autofit(1e-4,checkpoint_folder='checkpoint',epochs=12, early_stopping=True)
#early_stopping tells us to stop when the loss has been minimized
#accuracy is a valid measurement since we have balanced data
#if both the validation loss and training loss are both decreasing, we need to continue fitting
#   Thus, we stop once validation test loss increases and training validation loss decreased
# Out:
# begin training using triangular learning rate policy with max lr of 0.0001...
# Epoch 1/12
# 754/754 [==============================] - 424s 546ms/step - loss: 0.3829 - accuracy: 0.8342 - val_loss: 0.3082 - val_accuracy: 0.8678
# Epoch 2/12
# 754/754 [==============================] - ETA: 0s - loss: 0.2455 - accuracy: 0.9065Restoring model weights from the end of the best epoch: 1.
# 754/754 [==============================] - 413s 543ms/step - loss: 0.2455 - accuracy: 0.9065 - val_loss: 0.3129 - val_accuracy: 0.8678
# Epoch 00002: early stopping
# Weights from best epoch have been loaded into model.

# %%
learner.save_model("%s/distilbertmodel_learner" % DATA_DIR)

# %%
predictor = ktrain.get_predictor(learner.model, preproc=preprocess)
predictor.save("%s/distilbertmodel_predictor")

# %%
validation = learner.validate(val_data=val, print_report=True)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.84      0.86       655
#            1       0.86      0.89      0.87       684
#
#     accuracy                           0.87      1339
#    macro avg       0.87      0.87      0.87      1339
# weighted avg       0.87      0.87      0.87      1339

# %% [markdown]
# Hey, that's a pretty good set of performance metrics. Interpreted, that means for every 100 articles that we would target for healthy living, 84 of them would actually be healthy living. Recall here means that of all the possible healthy living articles that we could have gotten, we get 90% of all possible. Not too bad!

# %% [markdown]
# # Inspecting the drivers of prediction

# %% [markdown]
# No matter what the supervised machine learning model, you always want to peak under the hood to see what features are driving prediction. That is, what words sway the outcome of the prediction. It's harder to inspect a neural network. Because all of the layers of a neural network aren't really interpretable to the human eye.
#
# Currently, the best practice I've found is a little tool Explainable AI:
# https://alvinntnu.github.io/python-notes/nlp/ktrain-tutorial-explaining-predictions.html

# %%
# !pip3 install -q git+https://github.com/amaiya/eli5@tfkeras_0_10_1
# Out:
#   Building wheel for eli5 (setup.py) ... done

# %% [markdown]
# Let's go ahead and make a little set of test documents to check out

# %%
test_docs = [
'Stress May Be Your Heart’s Worst Enemy Psychological stress activates the fear center in the brain, setting into motion a cascade of reactions that can lead to heart attacks and strokes.',
'Exercising to Slim Down? Try Getting Bigger. It’s high time for women to reclaim the real strength behind exercise.',
'What Are Your Food Resolutions for the New Year? Join us for the Eat Well Challenge starting in January.',
'Why We All Need to Have More Fun. Prioritizing fun may feel impossible right now. But this four-step plan will help you rediscover how to feel more alive.',
'Cuomo Will Not Be Prosecuted in Groping Case, Albany D.A. Says. The district attorney described the woman who said former Gov. Andrew Cuomo had groped her as “credible,” but added that proving her allegation would be difficult.',
'A Film Captures Jewish Life in a Polish Town Before the Nazis Arrived. A documentary based on a home movie shot by an American in 1938 provides a look at the vibrancy of a Jewish community in Europe just before the Holocaust.' 
             ]

# %%
for i, text in enumerate(test_docs):
  probs = predictor.predict(text, return_proba=True)
  print("---------------------------")
  print('The probability this is healthy is %s' % probs[1])
  print(text)
# Out:
# ---------------------------
# The probability this is healthy is 0.9599182
# Stress May Be Your Heart’s Worst Enemy Psychological stress activates the fear center in the brain, setting into motion a cascade of reactions that can lead to heart attacks and strokes.
# ---------------------------
# The probability this is healthy is 0.92785066
# Exercising to Slim Down? Try Getting Bigger. It’s high time for women to reclaim the real strength behind exercise.
# ---------------------------
# The probability this is healthy is 0.91612244
# What Are Your Food Resolutions for the New Year? Join us for the Eat Well Challenge starting in January.
# ---------------------------
# The probability this is healthy is 0.80050933
# Why We All Need to Have More Fun. Prioritizing fun may feel impossible right now. But this four-step plan will help you rediscover how to feel more alive.
# ---------------------------
# The probability this is healthy is 0.007621423
# Cuomo Will Not Be Prosecuted in Groping Case, Albany D.A. Says. The district attorney described the woman who said former Gov. Andrew Cuomo had groped her as “credible,” but added that proving her allegation would be difficult.
# ---------------------------
# The probability this is healthy is 0.009368931
# A Film Captures Jewish Life in a Polish Town Before the Nazis Arrived. A documentary based on a home movie shot by an American in 1938 provides a look at the vibrancy of a Jewish community in Europe just before the Holocaust.

# %% [markdown]
# *These* are pretty obvious examples, but it works exactly as expected!

# %%
predictor.explain('Diversity is the key to a healthy society. Here is what we need to do to make america a more equitable place to live for all.')
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y=healthy
#
# </b>
#
#
#     (probability <b>0.595</b>, score <b>0.384</b>)
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature contribution already accounts for the feature value (for linear models, contribution = weight * feature value), and the sum of feature contributions is equal to the score or, for some classifiers, to the probability. Feature values are shown if &quot;show_feature_values&quot; is True.">
#                     Contribution<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
#         <tbody>
#
#             <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         +0.698
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         &lt;BIAS&gt;
#     </td>
#
# </tr>
#
#
#
#
#
#             <tr style="background-color: hsl(0, 100.00%, 88.56%); border: none;">
#     <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#         -0.314
#     </td>
#     <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#         Highlighted in text (sum)
#     </td>
#
# </tr>
#
#
#         </tbody>
#     </table>
#
#
#
#
#
#     <p style="margin-bottom: 2.5em; margin-top:-0.5em;">
#         <span style="background-color: hsl(0, 100.00%, 73.39%); opacity: 0.91" title="-1.274">diversity</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 85.98%); opacity: 0.84" title="-0.510">is</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 97.75%); opacity: 0.80" title="0.037">the</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.61%); opacity: 0.81" title="0.097">key</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 91.99%); opacity: 0.82" title="0.229">to</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.17%); opacity: 0.80" title="-0.009">a</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 60.00%); opacity: 1.00" title="2.281">healthy</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 95.83%); opacity: 0.81" title="0.090">society</span><span style="opacity: 0.80">. </span><span style="background-color: hsl(0, 100.00%, 96.58%); opacity: 0.81" title="-0.068">here</span><span style="opacity: 0.80"> is </span><span style="background-color: hsl(120, 100.00%, 94.22%); opacity: 0.81" title="0.144">what</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 94.71%); opacity: 0.81" title="-0.127">we</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 95.39%); opacity: 0.81" title="-0.104">need</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 97.69%); opacity: 0.80" title="-0.039">to</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.05%); opacity: 0.80" title="-0.011">do</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.86%); opacity: 0.81" title="-0.060">to</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 88.98%); opacity: 0.83" title="-0.362">make</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 77.42%); opacity: 0.89" title="-1.008">america</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.40%); opacity: 0.81" title="0.073">a</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 96.38%); opacity: 0.81" title="0.074">more</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 92.25%); opacity: 0.82" title="-0.219">equitable</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 96.66%); opacity: 0.81" title="-0.066">place</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 99.91%); opacity: 0.80" title="-0.000">to</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 84.46%); opacity: 0.85" title="0.591">live</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(120, 100.00%, 98.51%); opacity: 0.80" title="0.021">for</span><span style="opacity: 0.80"> </span><span style="background-color: hsl(0, 100.00%, 93.31%); opacity: 0.82" title="-0.177">all</span><span style="opacity: 0.80">.</span>
#     </p>

# %% [markdown]
# But you can see, this algorithm is far from perfect. Here you can see that it's probably got too high of an emphasis on the word "healthy."

# %% [markdown]
# So what would I do next? Well, given that it's over reacting to worrds like health and equitable, I'd try introducing more negative examples into the data, times where healthy is used outside of health and wellness news. We can do this by changing our sample from 50/50 to something like 20/80, but of course, the more documents we process, the longer this model is going to take to make!
